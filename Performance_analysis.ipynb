# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-71bb6c82-1e96-46d6-93fe-b78501a9fd41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-71bb6c82-1e96-46d6-93fe-b78501a9fd41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile('student (1).zip', 'r') as zip_ref:
    zip_ref.extractall()

print(zip_ref.namelist())
# Out:
# ['student-mat.csv', 'student-por.csv', 'student-merge.R', 'student.txt']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student-mat.csv', sep=';')

df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
print("Shape of dataset:", df.shape)
# Out:
# Shape of dataset: (395, 33)

# %%
print(df.dtypes)
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df = df.drop_duplicates()

print("Shape after removing duplicates:", df.shape)
# Out:
# Shape after removing duplicates: (395, 33)

# %%
above_15 = df[df['G3'] > 15]

print("Number of students scoring above 15:", len(above_15))
# Out:
# Number of students scoring above 15: 40

# %%
correlation = df['studytime'].corr(df['G3'])

print("Correlation between Study Time and G3:", correlation)
# Out:
# Correlation between Study Time and G3: 0.09781968965319626

# %%
gender_avg = df.groupby('sex')['G3'].mean()

print("Female Average G3:", gender_avg['F'])
print("Male Average G3:", gender_avg['M'])
# Out:
# Female Average G3: 9.966346153846153
# Male Average G3: 10.914438502673796

# %%
plt.figure(figsize=(8,5))
plt.hist(df['G3'], bins=10, edgecolor='black')
plt.title("Distribution of Final Grades")
plt.xlabel("Final Grade (G3)")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['studytime'], df['G3'])
plt.title("Study Time vs Final Grade")
plt.xlabel("Study Time")
plt.ylabel("Final Grade (G3)")
plt.show()

# %%
gender_avg.plot(kind='bar')

plt.title("Average Final Grade by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Grade (G3)")
plt.show()

# %% [markdown]
# # Student Performance Data Analysis
# ## Data Science with Python Internship – Task 1## Objective
#
# The objective of this project is to explore and analyze the Student Performance dataset using Python. This project follows a complete data analysis workflow, including loading the dataset, cleaning and preprocessing the data, performing statistical analysis, creating meaningful visualizations, and drawing insights based on the results.
# ## Analysis Results
#
# - Average Final Grade (G3): **10.42**
# - Students scoring above 15: **40**
# - Correlation between study time and G3: **0.098**, indicating a very weak positive relationship.
# - Male students achieved a slightly higher average final grade (10.91) than female students (9.97).
# ## Conclusion
#
# The Student Performance dataset was successfully explored and analyzed using Python, Pandas, and Matplotlib. The analysis provided useful insights into students' academic performance and study patterns.
#
# ### Key Findings
# - The dataset consists of **395 records** and **33 attributes**.
# - No missing values or duplicate entries were found during data cleaning.
# - The average final grade (**G3**) is **10.42**.
# - **40 students** achieved a final grade higher than **15**.
# - The relationship between study time and final grades is **very weak but positive**.
# - On average, **male students scored slightly higher** than female students.
#
# Overall, this project demonstrated the complete data analysis process, including data loading, preprocessing, exploratory analysis, visualization, and interpretation of results using Python.
